# %%
from fastai import *        # Quick access to most common functionality
from fastai.text import *   # Quick access to NLP functionality
from pathlib import Path
from fastai.vision import *

epochs = 20

# %%
accuracy_list = []

# %%
path_clas = Path('/home/ubuntu/data/autopsy/no_preprocessing')

batch_size=32

drop_mult=0.3
learning_rate= 1e-3
wd=1e-7
num_folds = 5

#folds only include training data
folds = ['data_suicide_homicide_k_1.csv','data_suicide_homicide_k_2.csv','data_suicide_homicide_k_3.csv','data_suicide_homicide_k_4.csv','data_suicide_homicide_k_5.csv']

# %%
data_clas = TextClasDataBunch.from_csv(path_clas,folds[0], classes=['Suicide','Homicide'], bs=batch_size)

learn = text_classifier_learner(data_clas, drop_mult=drop_mult, emb_sz=300, nh=198, nl=1)
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit(epochs,learning_rate, wd=wd)
# Out:
# Total time: 02:50
# epoch  train_loss  valid_loss  accuracy
# 1      0.663849    0.640182    0.712446  (00:07)
# 2      0.570011    0.558709    0.712446  (00:09)
# 3      0.516228    0.469233    0.785408  (00:08)
# 4      0.479201    0.364361    0.806867  (00:08)
# 5      0.451564    0.444687    0.811159  (00:08)
# 6      0.423754    0.494572    0.742489  (00:09)
# 7      0.455334    0.272041    0.888412  (00:08)
# 8      0.428086    0.311334    0.871245  (00:08)
# 9      0.404581    0.272827    0.884120  (00:08)
# 10     0.383265    0.261291    0.901288  (00:07)
# 11     0.353982    0.382974    0.828326  (00:07)
# 12     0.325182    0.274643    0.866953  (00:08)
# 13     0.328686    0.258296    0.884120  (00:09)
# 14     0.345384    0.247779    0.905579  (00:07)
# 15     0.323005    0.257445    0.896996  (00:08)
# 16     0.317633    0.273183    0.896996  (00:08)
# 17     0.260989    0.219003    0.922747  (00:09)
# 18     0.306342    0.270723    0.901288  (00:07)
# 19     0.287116    0.319927    0.875537  (00:08)
# 20     0.269636    0.480119    0.836910  (00:08)

# %%
learn.validate()
# Out:
# [0.48011866, tensor(0.8369)]

# %%
accuracy_list.append(learn.validate()[1].item())

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(4,4), dpi=120)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
data_clas = TextClasDataBunch.from_csv(path_clas,folds[1], classes=['Suicide','Homicide'], bs=batch_size)

learn = text_classifier_learner(data_clas, drop_mult=drop_mult, emb_sz=300, nh=198, nl=1)
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit(epochs,learning_rate, wd=wd)
# Out:
# Total time: 02:46
# epoch  train_loss  valid_loss  accuracy
# 1      0.646693    0.672470    0.716738  (00:08)
# 2      0.618750    0.537070    0.742489  (00:07)
# 3      0.560869    0.380966    0.841202  (00:09)
# 4      0.522422    0.491377    0.768240  (00:08)
# 5      0.458030    0.277160    0.875537  (00:08)
# 6      0.446339    0.253078    0.892704  (00:09)
# 7      0.449476    0.299464    0.892704  (00:08)
# 8      0.420371    0.410124    0.845494  (00:08)
# 9      0.398755    0.290637    0.875537  (00:07)
# 10     0.438555    0.271716    0.879828  (00:07)
# 11     0.355590    0.286494    0.879828  (00:08)
# 12     0.363605    0.287783    0.879828  (00:08)
# 13     0.355349    0.309846    0.875537  (00:07)
# 14     0.354486    0.406076    0.849785  (00:07)
# 15     0.352933    0.306140    0.879828  (00:09)
# 16     0.373088    0.318012    0.896996  (00:07)
# 17     0.309626    0.449722    0.815451  (00:09)
# 18     0.335160    0.279702    0.896996  (00:07)
# 19     0.317487    0.275558    0.896996  (00:07)
# 20     0.302868    0.338109    0.871245  (00:08)

# %%
learn.validate()
# Out:
# [0.33810937, tensor(0.8712)]

# %%
accuracy_list.append(learn.validate()[1].item())

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(4,4), dpi=120)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
data_clas = TextClasDataBunch.from_csv(path_clas,folds[2], classes=['Suicide','Homicide'], bs=batch_size)

learn = text_classifier_learner(data_clas, drop_mult=drop_mult, emb_sz=300, nh=198, nl=1)
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit(epochs,learning_rate, wd=wd)
# Out:
# Total time: 02:48
# epoch  train_loss  valid_loss  accuracy
# 1      0.664735    0.637970    0.729614  (00:08)
# 2      0.606135    0.629021    0.643777  (00:08)
# 3      0.557751    0.439055    0.858369  (00:09)
# 4      0.513947    0.387730    0.849785  (00:09)
# 5      0.467505    0.360054    0.858369  (00:07)
# 6      0.462655    0.359340    0.884120  (00:08)
# 7      0.439006    0.420781    0.811159  (00:07)
# 8      0.389749    0.466436    0.828326  (00:08)
# 9      0.341964    0.273117    0.888412  (00:09)
# 10     0.338486    0.282086    0.875537  (00:08)
# 11     0.344393    0.242802    0.905579  (00:08)
# 12     0.351668    0.294898    0.896996  (00:07)
# 13     0.323816    0.320665    0.866953  (00:08)
# 14     0.309921    0.242790    0.901288  (00:08)
# 15     0.313591    0.251779    0.896996  (00:07)
# 16     0.310358    0.276163    0.896996  (00:07)
# 17     0.350621    0.533716    0.772532  (00:08)
# 18     0.314107    0.269228    0.892704  (00:08)
# 19     0.297215    0.254405    0.875537  (00:07)
# 20     0.286670    0.218464    0.918455  (00:09)

# %%
learn.validate()
# Out:
# [0.21846402, tensor(0.9185)]

# %%
accuracy_list.append(learn.validate()[1].item())

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(4,4), dpi=120)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
data_clas = TextClasDataBunch.from_csv(path_clas,folds[3], classes=['Suicide','Homicide'], bs=batch_size)

learn = text_classifier_learner(data_clas, drop_mult=drop_mult, emb_sz=300, nh=198, nl=1)
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit(epochs,learning_rate, wd=wd)
# Out:
# Total time: 02:33
# epoch  train_loss  valid_loss  accuracy
# 1      0.676189    0.667820    0.656652  (00:08)
# 2      0.625708    0.542354    0.721030  (00:07)
# 3      0.553154    0.649710    0.652360  (00:08)
# 4      0.524520    0.408807    0.811159  (00:08)
# 5      0.475120    0.337864    0.871245  (00:09)
# 6      0.400741    0.296878    0.884120  (00:09)
# 7      0.400091    0.387972    0.836910  (00:07)
# 8      0.395493    0.241916    0.896996  (00:04)
# 9      0.394806    0.251906    0.896996  (00:03)
# 10     0.387490    0.382633    0.854077  (00:05)
# 11     0.371101    0.282302    0.879828  (00:07)
# 12     0.348296    0.224761    0.905579  (00:09)
# 13     0.353473    0.360249    0.858369  (00:07)
# 14     0.354952    0.227392    0.914163  (00:06)
# 15     0.303773    0.269135    0.892704  (00:08)
# 16     0.268672    0.237365    0.896996  (00:08)
# 17     0.328325    0.437524    0.815451  (00:07)
# 18     0.307296    0.250396    0.884120  (00:07)
# 19     0.284878    0.293004    0.888412  (00:08)
# 20     0.315992    0.236499    0.901288  (00:08)

# %%
learn.validate()
# Out:
# [0.23649931, tensor(0.9013)]

# %%
accuracy_list.append(learn.validate()[1].item())

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(4,4), dpi=120)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
data_clas = TextClasDataBunch.from_csv(path_clas,folds[4], classes=['Suicide','Homicide'], bs=batch_size)

learn = text_classifier_learner(data_clas, drop_mult=drop_mult, emb_sz=300, nh=198, nl=1)
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit(epochs,learning_rate, wd=wd)
# Out:
# Total time: 02:47
# epoch  train_loss  valid_loss  accuracy
# 1      0.673357    0.649785    0.768240  (00:07)
# 2      0.621356    0.471256    0.832618  (00:09)
# 3      0.574442    0.741760    0.626609  (00:08)
# 4      0.523778    0.566384    0.708154  (00:09)
# 5      0.509533    0.403140    0.849785  (00:07)
# 6      0.485836    0.408623    0.802575  (00:08)
# 7      0.421559    0.337192    0.841202  (00:08)
# 8      0.407694    0.317310    0.888412  (00:07)
# 9      0.413950    0.329845    0.879828  (00:07)
# 10     0.393898    0.351141    0.858369  (00:07)
# 11     0.367641    0.414164    0.832618  (00:08)
# 12     0.358110    0.334255    0.871245  (00:08)
# 13     0.356650    0.284789    0.892704  (00:09)
# 14     0.361330    0.328545    0.879828  (00:07)
# 15     0.291935    0.274587    0.884120  (00:09)
# 16     0.320345    0.277401    0.884120  (00:07)
# 17     0.305033    0.359317    0.866953  (00:08)
# 18     0.307705    0.298436    0.892704  (00:08)
# 19     0.307319    0.290076    0.901288  (00:09)
# 20     0.354626    0.262537    0.909871  (00:08)

# %%
learn.validate()
# Out:
# [0.26253662, tensor(0.9099)]

# %%
accuracy_list.append(learn.validate()[1].item())

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(4,4), dpi=120)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
print(accuracy_list)
# Out:
# [0.8369098901748657, 0.8712446093559265, 0.9184549450874329, 0.9012875556945801, 0.9098712205886841]

# %%
print(sum(accuracy_list)/len(accuracy_list))
# Out:
# 0.8875536441802978

# %%
data_clas = TextClasDataBunch.from_csv(path_clas,'data_suicide_homicide_combined_train_test.csv', classes=['Suicide','Homicide'], bs=batch_size)

learn = text_classifier_learner(data_clas, drop_mult=drop_mult, emb_sz=300, nh=198, nl=1)
learn.freeze()

# %%
learn.unfreeze()
learn.fit(epochs,learning_rate, wd=wd)
# Out:
# Total time: 03:07
# epoch  train_loss  valid_loss  accuracy
# 1      0.637591    0.649313    0.706564  (00:09)
# 2      0.568679    0.391684    0.884170  (00:09)
# 3      0.555613    0.405875    0.868726  (00:08)
# 4      0.523675    0.350389    0.884170  (00:08)
# 5      0.413871    0.310772    0.876448  (00:10)
# 6      0.366805    0.326431    0.868726  (00:10)
# 7      0.357539    0.244205    0.880309  (00:09)
# 8      0.316352    0.223184    0.907336  (00:09)
# 9      0.316192    0.237001    0.899614  (00:09)
# 10     0.310317    0.304069    0.861004  (00:09)
# 11     0.324776    0.258465    0.880309  (00:08)
# 12     0.284442    0.229029    0.915058  (00:09)
# 13     0.348981    0.281889    0.884170  (00:08)
# 14     0.343629    0.380075    0.857143  (00:08)
# 15     0.311851    0.248075    0.903475  (00:09)
# 16     0.278505    0.287591    0.876448  (00:08)
# 17     0.295125    0.273325    0.891892  (00:08)
# 18     0.226033    0.303360    0.880309  (00:10)
# 19     0.252200    0.300742    0.888031  (00:08)
# 20     0.193985    0.265023    0.903475  (00:10)

# %%
learn.validate()
# Out:
# [0.265023, tensor(0.9035)]

# %%
accuracy_list.append(learn.validate()[1].item())

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(4,4), dpi=120)

# %%
import torch

torch.cuda.empty_cache()
