# %%
from fastai import *        # Quick access to most common functionality
from fastai.text import *   # Quick access to NLP functionality
from pathlib import Path
from fastai.vision import *
import statistics

epochs = 20

# %%
accuracy_list = []

# %%
path_clas = Path('/home/ubuntu/data/autopsy/2014_2018/no_preprocessing')

batch_size=32

drop_mult=0.3
learning_rate= 1e-3
wd=1e-4
num_folds = 5

folds = ['data_suicide_homicide_k_1.csv','data_suicide_homicide_k_2.csv','data_suicide_homicide_k_3.csv','data_suicide_homicide_k_4.csv','data_suicide_homicide_k_5.csv']

# %%
data_clas = TextClasDataBunch.from_csv(path_clas,folds[0], classes=['Suicide','Homicide'], bs=batch_size)

learn = text_classifier_learner(data_clas, drop_mult=drop_mult, emb_sz=300, nh=198, nl=1)
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit(epochs,learning_rate, wd=wd)
# Out:
# Total time: 07:13
# epoch  train_loss  valid_loss  accuracy
# 1      0.613607    0.440107    0.847291  (00:23)
# 2      0.544562    0.363895    0.906404  (00:20)
# 3      0.461626    0.374430    0.881773  (00:23)
# 4      0.469318    0.271684    0.931035  (00:19)
# 5      0.403295    0.279867    0.893268  (00:23)
# 6      0.371728    0.267908    0.909688  (00:23)
# 7      0.354258    0.256262    0.908046  (00:20)
# 8      0.327085    0.192155    0.935961  (00:24)
# 9      0.292192    0.201391    0.950739  (00:23)
# 10     0.351048    0.203179    0.942529  (00:19)
# 11     0.308815    0.217645    0.934319  (00:20)
# 12     0.290597    0.185244    0.944171  (00:21)
# 13     0.312768    0.176558    0.939245  (00:22)
# 14     0.359685    0.190239    0.942529  (00:20)
# 15     0.301803    0.238065    0.917898  (00:22)
# 16     0.273511    0.183936    0.937603  (00:21)
# 17     0.322172    0.184414    0.937603  (00:19)
# 18     0.274313    0.289523    0.899836  (00:21)
# 19     0.269041    0.180031    0.940887  (00:20)
# 20     0.253502    0.198977    0.932676  (00:21)

# %%
learn.validate()
# Out:
# [0.1989773, tensor(0.9327)]

# %%
accuracy_list.append(learn.validate()[1].item())

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(4,4), dpi=120)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
data_clas = TextClasDataBunch.from_csv(path_clas,folds[1], classes=['Suicide','Homicide'], bs=batch_size)

learn = text_classifier_learner(data_clas, drop_mult=drop_mult, emb_sz=300, nh=198, nl=1)
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit(epochs,learning_rate, wd=wd)
# Out:
# Total time: 07:14
# epoch  train_loss  valid_loss  accuracy
# 1      0.608990    0.517351    0.781609  (00:21)
# 2      0.563293    0.446139    0.845649  (00:21)
# 3      0.524519    0.356130    0.908046  (00:18)
# 4      0.451234    0.270419    0.924466  (00:24)
# 5      0.405498    0.284766    0.868637  (00:24)
# 6      0.414236    0.218724    0.929392  (00:21)
# 7      0.362405    0.193386    0.937603  (00:22)
# 8      0.323449    0.207573    0.926108  (00:25)
# 9      0.388831    0.228463    0.916256  (00:21)
# 10     0.306143    0.233731    0.908046  (00:21)
# 11     0.273442    0.195373    0.934319  (00:21)
# 12     0.332879    0.242341    0.922824  (00:19)
# 13     0.303811    0.201686    0.931035  (00:21)
# 14     0.330318    0.186699    0.940887  (00:19)
# 15     0.292790    0.245902    0.921182  (00:22)
# 16     0.281845    0.190448    0.935961  (00:21)
# 17     0.272172    0.195837    0.932676  (00:20)
# 18     0.317092    0.174049    0.937603  (00:23)
# 19     0.271239    0.190120    0.935961  (00:20)
# 20     0.268997    0.246903    0.924466  (00:21)

# %%
learn.validate()
# Out:
# [0.24690346, tensor(0.9245)]

# %%
accuracy_list.append(learn.validate()[1].item())

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(4,4), dpi=120)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
data_clas = TextClasDataBunch.from_csv(path_clas,folds[2], classes=['Suicide','Homicide'], bs=batch_size)

learn = text_classifier_learner(data_clas, drop_mult=drop_mult, emb_sz=300, nh=198, nl=1)
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit(epochs,learning_rate, wd=wd)
# Out:
# Total time: 07:15
# epoch  train_loss  valid_loss  accuracy
# 1      0.577611    0.522709    0.784893  (00:23)
# 2      0.530429    0.324681    0.926108  (00:23)
# 3      0.495613    0.359738    0.855501  (00:23)
# 4      0.469080    0.316070    0.888342  (00:20)
# 5      0.406692    0.363994    0.853859  (00:23)
# 6      0.391961    0.267357    0.927750  (00:20)
# 7      0.384387    0.247011    0.929392  (00:19)
# 8      0.343025    0.224644    0.932676  (00:20)
# 9      0.340885    0.304712    0.914614  (00:20)
# 10     0.262126    0.297653    0.880131  (00:24)
# 11     0.323983    0.162946    0.949097  (00:23)
# 12     0.307385    0.257172    0.914614  (00:23)
# 13     0.337806    0.212097    0.916256  (00:19)
# 14     0.262612    0.185709    0.931035  (00:21)
# 15     0.339616    0.204157    0.932676  (00:19)
# 16     0.234427    0.203400    0.917898  (00:24)
# 17     0.248932    0.213535    0.924466  (00:20)
# 18     0.256585    0.191630    0.929392  (00:24)
# 19     0.260172    0.157230    0.949097  (00:19)
# 20     0.270165    0.291711    0.891626  (00:21)

# %%
learn.validate()
# Out:
# [0.2917113, tensor(0.8916)]

# %%
accuracy_list.append(learn.validate()[1].item())

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(4,4), dpi=120)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
data_clas = TextClasDataBunch.from_csv(path_clas,folds[3], classes=['Suicide','Homicide'], bs=batch_size)

learn = text_classifier_learner(data_clas, drop_mult=drop_mult, emb_sz=300, nh=198, nl=1)
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit(epochs,learning_rate, wd=wd)
# Out:
# Total time: 07:12
# epoch  train_loss  valid_loss  accuracy
# 1      0.619100    0.625139    0.669951  (00:20)
# 2      0.553906    0.442201    0.866995  (00:21)
# 3      0.525109    0.424538    0.837438  (00:24)
# 4      0.460577    0.299719    0.886699  (00:21)
# 5      0.440592    0.276829    0.919540  (00:23)
# 6      0.363820    0.281649    0.883415  (00:19)
# 7      0.363503    0.197530    0.940887  (00:20)
# 8      0.319511    0.241514    0.916256  (00:20)
# 9      0.297902    0.238747    0.917898  (00:23)
# 10     0.322855    0.220360    0.914614  (00:24)
# 11     0.318889    0.300146    0.896552  (00:21)
# 12     0.323828    0.241776    0.912972  (00:19)
# 13     0.263497    0.237208    0.914614  (00:24)
# 14     0.305848    0.197993    0.922824  (00:19)
# 15     0.283315    0.205618    0.932676  (00:19)
# 16     0.266864    0.226418    0.914614  (00:21)
# 17     0.319854    0.236946    0.916256  (00:22)
# 18     0.280021    0.243582    0.926108  (00:23)
# 19     0.280018    0.295630    0.899836  (00:21)
# 20     0.225753    0.230651    0.924466  (00:21)

# %%
learn.validate()
# Out:
# [0.23065095, tensor(0.9245)]

# %%
accuracy_list.append(learn.validate()[1].item())

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(4,4), dpi=120)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
data_clas = TextClasDataBunch.from_csv(path_clas,folds[4], classes=['Suicide','Homicide'], bs=batch_size)

learn = text_classifier_learner(data_clas, drop_mult=drop_mult, emb_sz=300, nh=198, nl=1)
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit(epochs,learning_rate, wd=wd)
# Out:
# Total time: 07:18
# epoch  train_loss  valid_loss  accuracy
# 1      0.609157    0.542421    0.827586  (00:21)
# 2      0.538677    0.495025    0.829228  (00:23)
# 3      0.520946    0.285143    0.883415  (00:19)
# 4      0.474845    0.322350    0.883415  (00:22)
# 5      0.408478    0.232673    0.912972  (00:23)
# 6      0.407061    0.256174    0.931035  (00:24)
# 7      0.381716    0.214282    0.926108  (00:20)
# 8      0.331044    0.224299    0.944171  (00:24)
# 9      0.354850    0.176232    0.954023  (00:19)
# 10     0.364166    0.178928    0.940887  (00:19)
# 11     0.272629    0.168042    0.942529  (00:23)
# 12     0.268760    0.363551    0.852217  (00:23)
# 13     0.258879    0.181920    0.937603  (00:20)
# 14     0.314331    0.236035    0.927750  (00:20)
# 15     0.277850    0.212786    0.934319  (00:21)
# 16     0.270935    0.187708    0.942529  (00:19)
# 17     0.315108    0.177220    0.934319  (00:22)
# 18     0.337506    0.217493    0.922824  (00:20)
# 19     0.234658    0.195371    0.929392  (00:24)
# 20     0.317927    0.202508    0.926108  (00:20)

# %%
learn.validate()
# Out:
# [0.20250826, tensor(0.9261)]

# %%
accuracy_list.append(learn.validate()[1].item())

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(4,4), dpi=120)

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_metrics()

# %%
print(accuracy_list)
# Out:
# [0.9326764941215515, 0.9244663119316101, 0.8916256427764893, 0.9244663119316101, 0.9261083602905273]

# %%
print(sum(accuracy_list)/len(accuracy_list))
# Out:
# 0.9198686242103576

# %%
print(statistics.variance(accuracy_list))
# Out:
# 0.00026072982576259563

# %%
import torch

torch.cuda.empty_cache()
